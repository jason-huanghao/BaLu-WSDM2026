# %%
import numpy as np
import torch 
a = np.array([0., np.nan, 1])
b = torch.tensor(a, dtype=torch.float)
b
# Out:
# tensor([0., nan, 1.])

# %%
def to_device(*obs):
    print(obs)

to_device(1,2,3,4)
# Out:
# (1, 2, 3, 4)
